# %%
cd ../myliggghts/microMacro/results/05Nmu005
# Out:
# /home/jon/myliggghts/microMacro/results/05Nmu005

# %%
import pandas as pd

# %%
df = pd.read_csv('strain05p.csv')
force = df.pressure
area = df.Area
pressure = force/area/10**6
compress = pressure[0:50]
decompress = pressure[49:101]
strain1 = linspace(0,0.5,50)
strain2 = linspace(0.5,0,52)

plot(strain1,compress,'r')
plot(strain2,decompress,'b')
legend(['Pressure','Relaxation'],4)
xlabel('strain (%)')
ylabel('stress (MPa)')
title('stress-strain diagram for 0.5% strain')

# %%
df = pd.read_csv('strain1p.csv')
force = df.pressure
area = df.Area
pressure = force/area/10**6
compress = pressure[0:50]
decompress = pressure[49:101]
strain1 = linspace(0,1,50)
strain2 = linspace(1,0,52)

plot(strain1,compress,'r')
plot(strain2,decompress,'b')
legend(['Pressure','Relaxation'],4)
xlabel('strain (%)')
ylabel('stress (MPa)')
title('stress-strain diagram for 1% strain')

# %%
df = pd.read_csv('strain125p.csv')
force = df.pressure
area = df.Area
pressure = force/area/10**6
compress = pressure[0:100]
decompress = pressure[99:201]
strain1 = linspace(0,1.25,100)
strain2 = linspace(1.25,0,102)
print len(force)
plot(strain1,compress,'r')
plot(strain2,decompress,'b')
legend(['Pressure','Relaxation'],4)
xlabel('strain (%)')
ylabel('stress (MPa)')
title('stress-strain diagram for 1.5% strain')
# Out:
# 201

# %%
df = pd.read_csv('strain15p.csv')
force = df.pressure
area = df.Area
pressure = force/area/10**6
compress = pressure[0:100]
decompress = pressure[99:201]
strain1 = linspace(0,1.5,100)
strain2 = linspace(1.5,0,102)

plot(strain1,compress,'r')
plot(strain2,decompress,'b')
legend(['Pressure','Relaxation'],4)
xlabel('strain (%)')
ylabel('stress (MPa)')
title('stress-strain diagram for 1.5% strain')

# %%
df1 = pd.read_csv('strain05p.csv')
df2 = pd.read_csv('strain1p.csv')
df3 = pd.read_csv('strain125p.csv')
#df4 = pd.read_csv('strain15p.csv')

force1 = df1.pressure
force2 = df2.pressure
force3 = df3.pressure
#force4 = df4.pressure

area1 = df1.Area
area2 = df2.Area
area3 = df3.Area
#area4 = df4.Area

pressure1 = force1/area1/10**6
pressure2 = force2/area2/10**6
pressure3 = force3/area3/10**6
#pressure4 = force4/area4/10**6

compress1 = pressure1[0:50]
compress2 = pressure2[0:50]
compress3 = pressure3[0:100]
#compress4 = pressure4[0:100]

decompress1 = pressure1[49:101]
decompress2 = pressure2[49:101]
decompress3 = pressure3[99:201]
#decompress4 = pressure4[99:201]

strain11 = linspace(0,0.5,50)
strain21 = linspace(0.5,0,52)
strain12 = linspace(0,1.,50)
strain22 = linspace(1.,0,52)
strain13 = linspace(0,1.25,100)
strain23 = linspace(1.25,0,102)
strain14 = linspace(0,1.5,100)
strain24 = linspace(1.5,0,102)

plot(strain11,compress1,'r')
plot(strain21,decompress1,'b')
plot(strain12,compress2,'r')
plot(strain22,decompress2,'b')
plot(strain13,compress3,'r')
plot(strain23,decompress3,'b')
#plot(strain14,compress4,'r')
#plot(strain24,decompress4,'b')

legend(['Pressure','Relaxation'],2)
xlabel('strain (%)')
ylabel('stress (MPa)')
title('Stress of virgin compressions on orthosilicate')
