# %%
cd ../myliggghts/microMacro/post/strainCycle/
# Out:
# /home/jon/myliggghts/microMacro/post/strainCycle

# %%
import pandas as pd

# %%
df = pd.read_csv('strainCycle.csv')

force = df.pressure
area = df.Area

pressure = force/area/10**6

# %%
plot(pressure)
len(pressure)
# Out:
# 501

# %%
compress1 = pressure[0:50]
compress2 = pressure[100:150]
compress3 = pressure[200:250]
compress4 = pressure[300:400]

decompress1 = pressure[49:101]
decompress2 = pressure[149:201]
decompress3 = pressure[249:301]
decompress4 = pressure[399:501]

print len(decompress3)

strain11 = linspace(0,0.5,50)
strain21 = linspace(0.5,0,52)
strain12 = linspace(0,0.5,50)
strain22 = linspace(0.5,0,52)
strain13 = linspace(0,1.,50)
strain23 = linspace(1.,0,52)
strain14 = linspace(0,1.25,100)
strain24 = linspace(1.25,0,102)



plot(strain11,compress1,'r')
plot(strain21,decompress1,'b')
plot(strain12,compress2,'r')
plot(strain22,decompress2,'b')
plot(strain13,compress3,'r')
plot(strain23,decompress3,'b')
plot(strain14,compress4,'r')
plot(strain24,decompress4,'b')#

legend(['Pressure','Relaxation'],2)
xlabel('strain (%)')
ylabel('stress (MPa)')
title('Stress of virgin compressions on orthosilicate')
# Out:
# 52
