# %%
import pandas as pd
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 12, 6  # that's default image size for this interactive session

# %%
ep = 0.1
E = 266.8*(1-ep)*(1-1.2*ep)**2.
print E
# Out:
# 185.948928

# %%
def hertz( nu1, E1, nu2, E2, dp, s ):
    # given:
    # Young's Moduli - E in GPa
    # Pebble diameter - dp in mm
    # displacement - s in mm
    dp = dp/1000.
    s = s/1000.
    E1 = E1*10**9.
    E2 = E2*10**9.
    Estar = 1./((1.-nu1**2.)/E1+(1.-nu2**2.)/E2)
    F = (1./3) * Estar2 * (s**3. * dp)**(1/2.)
    return F


s = linspace(0,0.1,1001) #0.1 mm strain

# Properties
dp = 1. #mm
E = {'Li4SiO4':90., 'SS':200.}
nu = {'Li4SiO4':0.27, 'SS':0.25}

F_n = hertz(nu['Li4SiO4'], E['Li4SiO4'], nu['SS'], E['SS'], dp, s)
plot(s, F_n, linewidth = 4)
grid(b=True, which='major', color='b', linestyle='-')
xlim([0, s[-1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a13be23967b6> in <module>()
#      21 nu = {'Li4SiO4':0.27, 'SS':0.25}
#      22
# ---> 23 F_n = hertz(nu['Li4SiO4'], E['Li4SiO4'], nu['SS'], E['SS'], dp, s)
#      24 plot(s, F_n, linewidth = 4)
#      25 grid(b=True, which='major', color='b', linestyle='-')
#
# <ipython-input-5-a13be23967b6> in hertz(nu1, E1, nu2, E2, dp, s)
#      10     E2 = E2*10**9.
#      11     Estar = 1./((1.-nu1**2.)/E1+(1.-nu2**2.)/E2)
# ---> 12     F = (1./3) * Estar2 * (s**3. * dp)**(1/2.)
#      13     return F
#      14
#
# NameError: global name 'Estar2' is not defined

# %%
# ELASTO-PLASTIC
sf = rp/1200.
pf = Estar/pi * (sf/rp)**(1/2.)
Fn_elpl = pi*rp*pf*(1-(1/3.)*(sf/s)**(1/3.))*s/2.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e8625103a60e> in <module>()
#       1 # ELASTO-PLASTIC
# ----> 2 sf = rp/1200.
#       3 pf = Estar/pi * (sf/rp)**(1/2.)
#       4 Fn_elpl = pi*rp*pf*(1-(1/3.)*(sf/s)**(1/3.))*s/2.
#
# NameError: name 'rp' is not defined

# %%
M = range(1,6)
for m in M:
    df = pd.read_csv('Li4SiO4/Specimen_RawData_'+str(m)+'.csv', skiprows=40)
    df.columns = ['time', 'displacement','force']
    
    arrayStart = argmax(abs(df.force)>0.05)
    
    disp = abs(df.displacement[arrayStart:])
    force = abs(df.force[arrayStart:])
    dispN = disp - disp[arrayStart]
     
    figure(1)
    plot(dispN,force, linewidth = 4)
    ylim([0, 100])
    xlim([0, 0.07])
    xlabel('displacement (mm)', fontsize=28)
    ylabel('load (N)', fontsize=28)

#plot(s, F_n, '--', linewidth = 4)
